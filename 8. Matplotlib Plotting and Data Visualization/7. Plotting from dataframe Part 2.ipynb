# %% [markdown]
# # Plotting from DataFrame

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# create a dataframe
car_sales = pd.read_csv(r'C:\Users\hafee\OneDrive\Desktop\MachineLearningDataScienceBootCamp\car_sales.csv')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Visualization
# https://pandas.pydata.org/docs/user_guide/visualization.html

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts
# Out:
# 2000-01-01    0.732495
# 2000-01-02   -0.624194
# 2000-01-03   -0.719896
# 2000-01-04    0.926987
# 2000-01-05    0.002542
#                 ...
# 2002-09-22   -0.456784
# 2002-09-23    0.304214
# 2002-09-24    0.609798
# 2002-09-25   -0.430834
# 2002-09-26   -0.492110
# Freq: D, Length: 1000, dtype: float64

# %%
ts = ts.cumsum()
ts
# Out:
# 2000-01-01     0.732495
# 2000-01-02     0.108301
# 2000-01-03    -0.611596
# 2000-01-04     0.315391
# 2000-01-05     0.317933
#                 ...
# 2002-09-22   -14.036731
# 2002-09-23   -13.732516
# 2002-09-24   -13.122718
# 2002-09-25   -13.553553
# 2002-09-26   -14.045663
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot();

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=["B", "C"]).cumsum()
df3["A"] = pd.Series(list(range(len(df))))
df3.plot(x="A", y="B");

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=["B", "C"]).cumsum()

df3["A"] = pd.Series(list(range(len(df))))

df3.plot(x="A", y="B");

# %%
plt.figure();
df.iloc[5].plot.bar();
plt.axhline(0, color="k");

# %% [markdown]
# ### Plotting from DataFrame

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
car_sales["Price"]
# Out:
# C:\Users\hafee\AppData\Local\Temp\ipykernel_16624\2605178068.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: object

# %%
type(car_sales["Price"])
# Out:
# pandas.core.series.Series

# %%
## Remove last two zeros
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales["Price"]
# Out:
# 0     40
# 1     50
# 2     70
# 3    220
# 4     35
# 5     45
# 6     75
# 7     70
# 8     62
# 9     97
# Name: Price, dtype: object

# %%
# Add a new column "Sale Date" int datafrmae containing date_range 1/1/2020 and onwards based on len(car_sales)
car_sales["Sale Date"] = pd.date_range('1/1/2020', periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors Price  Sale Date
# 0  Toyota  White         150043      4    40 2020-01-01
# 1   Honda    Red          87899      4    50 2020-01-02
# 2  Toyota   Blue          32549      3    70 2020-01-03
# 3     BMW  Black          11179      5   220 2020-01-04
# 4  Nissan  White         213095      4    35 2020-01-05
# 5  Toyota  Green          99213      4    45 2020-01-06
# 6   Honda   Blue          45698      4    75 2020-01-07
# 7   Honda   Blue          54738      4    70 2020-01-08
# 8  Toyota  White          60000      4    62 2020-01-09
# 9  Nissan  White          31600      4    97 2020-01-10

# %%
car_sales["Total Sales"] =  car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4    40 2020-01-01           40
# 1   Honda    Red          87899      4    50 2020-01-02           90
# 2  Toyota   Blue          32549      3    70 2020-01-03          160
# 3     BMW  Black          11179      5   220 2020-01-04          380
# 4  Nissan  White         213095      4    35 2020-01-05          415
# 5  Toyota  Green          99213      4    45 2020-01-06          460
# 6   Honda   Blue          45698      4    75 2020-01-07          535
# 7   Honda   Blue          54738      4    70 2020-01-08          605
# 8  Toyota  White          60000      4    62 2020-01-09          667
# 9  Nissan  White          31600      4    97 2020-01-10          764

# %%
## plot the total sales
car_sales.plot(x = "Sale Date", y = "Total Sales")
# Out:
# <Axes: xlabel='Sale Date'>

# %%
car_sales.plot(x = "Odometer (KM)", y= "Price", kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
# Bar Graph
x = np.random.rand(10, 4)
x
# Out:
# array([[0.50871317, 0.0022634 , 0.60732524, 0.46670382],
#        [0.96764221, 0.20508525, 0.40987752, 0.62030844],
#        [0.44225276, 0.78089348, 0.03465069, 0.72449261],
#        [0.68454675, 0.76015746, 0.28082671, 0.78759914],
#        [0.45491732, 0.41045579, 0.94643394, 0.5636512 ],
#        [0.36671495, 0.53676401, 0.78155274, 0.80039444],
#        [0.22312838, 0.21776593, 0.31674184, 0.65438222],
#        [0.31733891, 0.99437337, 0.93654278, 0.35147267],
#        [0.62277055, 0.029247  , 0.02090701, 0.4936987 ],
#        [0.31113366, 0.43199386, 0.00270409, 0.47659095]])

# %%
# Trun into Dataframe
dataframe = pd.DataFrame(x, columns=["a", "b" , "c" , "d"] )
dataframe
# Out:
#           a         b         c         d
# 0  0.508713  0.002263  0.607325  0.466704
# 1  0.967642  0.205085  0.409878  0.620308
# 2  0.442253  0.780893  0.034651  0.724493
# 3  0.684547  0.760157  0.280827  0.787599
# 4  0.454917  0.410456  0.946434  0.563651
# 5  0.366715  0.536764  0.781553  0.800394
# 6  0.223128  0.217766  0.316742  0.654382
# 7  0.317339  0.994373  0.936543  0.351473
# 8  0.622771  0.029247  0.020907  0.493699
# 9  0.311134  0.431994  0.002704  0.476591

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4    40 2020-01-01           40
# 1   Honda    Red          87899      4    50 2020-01-02           90
# 2  Toyota   Blue          32549      3    70 2020-01-03          160
# 3     BMW  Black          11179      5   220 2020-01-04          380
# 4  Nissan  White         213095      4    35 2020-01-05          415
# 5  Toyota  Green          99213      4    45 2020-01-06          460
# 6   Honda   Blue          45698      4    75 2020-01-07          535
# 7   Honda   Blue          54738      4    70 2020-01-08          605
# 8  Toyota  White          60000      4    62 2020-01-09          667
# 9  Nissan  White          31600      4    97 2020-01-10          764

# %%
car_sales.plot(x = "Make", y = "Odometer (KM)", kind = "bar")
# Out:
# <Axes: xlabel='Make'>

# %%
# Histogram
car_sales["Odometer (KM)"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind  = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot.hist(bins=40)
# Out:
# <Axes: ylabel='Frequency'>
