# %%
import numpy as np

# %% [markdown]
# ### Dot Product

# %%
np.random.seed(0)

matrix1 = np.random.randint(10, size = (5,3))
matrix2 = np.random.randint(10, size = (5,3))

# %%
matrix1
# Out:
# array([[5, 0, 3],
#        [3, 7, 9],
#        [3, 5, 2],
#        [4, 7, 6],
#        [8, 8, 1]])

# %%
matrix2
# Out:
# array([[6, 7, 7],
#        [8, 1, 5],
#        [9, 8, 9],
#        [4, 3, 0],
#        [3, 5, 0]])

# %%
mat1.shape, mat2.shape
# Out:
# ((5, 3), (5, 3))

# %%
# Element-wise multiplication (Hadamard Product)
matrix1  * matrix2
# Out:
# array([[30,  0, 21],
#        [24,  7, 45],
#        [27, 40, 18],
#        [16, 21,  0],
#        [24, 40,  0]])

# %%
# Dot Product
np.dot(matrix1, matrix2)

# This generate an error row and columns of both matrices do not follow dot product rules.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Dot Product
# ----> 2 np.dot(mat1, mat2)
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# ValueError: shapes (5,3) and (5,3) not aligned: 3 (dim 1) != 5 (dim 0)

# %% [markdown]
# ###
# ![image.png](attachment:image.png)

# %% [markdown]
# ###
# ![image.png](attachment:image.png)

# %%
# Transpose the mat1
matrix1.T
# Out:
# array([[5, 3, 3, 4, 8],
#        [0, 7, 5, 7, 8],
#        [3, 9, 2, 6, 1]])

# %%
matrix1.T.shape
# Out:
# (3, 5)

# %%
matrix2.shape , matrix1.T.shape
# Out:
# ((5, 3), (3, 5))

# %%
matrix3 = np.dot(matrix1, matrix2.T)

# %%
matrix3
# Out:
# array([[ 51,  55,  72,  20,  15],
#        [130,  76, 164,  33,  44],
#        [ 67,  39,  85,  27,  34],
#        [115,  69, 146,  37,  47],
#        [111,  77, 145,  56,  64]])

# %%
matrix3.shape
# Out:
# (5, 5)
